# %%
import requests
import openpyxl
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')
import pandas as pd
import numpy as np
from pymarc import MARCReader

# %%
def modify_isbn(isbn):
    isbn = str(isbn)
    # Check if the first 3 characters are neither '978' nor '979', and the length is 10
    if not (isbn[:3] == '978' or isbn[:3] == '979'):
        if len(isbn) == 10:
            return '978' + isbn  # Prepend '978' if conditions are met
    return isbn[:13]  # Return the first 13 characters of ISBN as-is if conditions are not met

# %%
# /Users/rwebb/Desktop/ReMo/CRWReportJob148737.xlsx

# %%
# Handle excel (.xlsx) files, scraping ISBNs --> Learn to convert other files
# Use API to fill data points
# Fill gaps with excel

# %%
filename = input('Enter File Name: ')
print('Selected:', filename)

if filename.endswith('.mrc'):
    file = open(filename, 'r')
elif filename.endswith('.xml'):
    file = open(filename, 'r')
elif filename.endswith('.xlsx'):
    file = pd.read_excel(filename)
    # print(file.head())  # Uncomment if you want to inspect the first few rows
    isbn_values = []
    
    # Ensure 'ISBN' column exists
    if 'ISBN' in file.columns:
        for isbn in file['ISBN']:
            if pd.isna(isbn):
                continue  # Skip if ISBN is NaN
            isbn = str(isbn)  # Ensure it's a string
            isbn = isbn.replace('-', '')  # Remove dashes
            # Check if the ISBN starts with '978' or '979'
            if not (isbn[:3] == '978' or isbn[:3] == '979'):
                if len(isbn) == 10:
                    isbn = '978' + isbn
                else:    
                    isbn_values.append('BAD DATA')
                continue  # Skip the current invalid ISBN
            isbn = isbn[:13]  # Ensure it's the correct length (13 digits)

            isbn_values.append(isbn)
        print(isbn_values)
    else:
        print("No 'ISBN' column found in the Excel file.")
else:
    print("Unsupported file format.")
df = file
# Out:
# Selected: CRWReportJob148737.xlsx
# ['9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007439126', '9780007511242', '9780007511242', '9780007511242', '9780007511242', '9780007511242', '9780007511242', '9780007511242', '9780007511242', '9780008183684', '9780008183684', '9780008183684', '9780008183684', '9780008183684', '9780008183684', '9780008256944', '9780008256944', 'BAD DATA', 'BAD DATA', 'BAD DATA', '9780060012786', '9780060012786', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', '9780060518509', '9780060518509', '9780060518509', '9780060518509', '9780060518509', '9780060518509', '9780060518509', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', '9780060590284', '9780060590284', '9780060590284', '9780060590284', '9780060590284', '9780060590284', '9780060590284', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060765453', '9780060776091', '9780060776091', '9780060776091', '9780060776091', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060779641', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060852566', '9780060853983', '9780060853983', '9780060853983', '9780060853983', '9780060855024', '9780060855024', '9780060855024', '9780060886394', '9780060886394', '9780060886394', '9780060886394', '9780060886394', '9780060886394', '9780060889661', '9780060889661', '9780060889661', '9780060889661', '9780060889661', '9780060889661', '9780060889661', '9780060889661', '9780060899226', '9780060899226', '9780060899226', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', '9780060935467', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', 'BAD DATA', '9780061120275', '9780061120275', '9780061120275', '9780061120275', '9780061120275', '9780061120275', '9780061120275', '9780061132186', '9780061132186', '9780061132186', '9780061132186', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134104', '9780061134111', '9780061134111', '9780061230974', '9780061230974', '9780061230974', '9780061230974', '9780061230974', '9780061230974', '9780061230974', '9780061243585', '9780061243585', '9780061243585', '9780061243585', '9780061243585', '9780061351327', '9780061351327', '9780061351327', '9780061351327', '9780061351327', '9780061351327', '9780061374050', '9780061374050', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061469084', '9780061537967', '9780061537967', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311', '9780061565311 ...

# %%
nan_df = df[df['ISBN'].isna()]
isbn_df = df[~df['ISBN'].isna()]

# %%
isbn_df.loc[:, 'ISBN'] = isbn_df['ISBN'].str.replace('-', '', regex=False)
isbn_df.loc[:, 'ISBN'] = isbn_df['ISBN'].apply(modify_isbn)

# %%
broken_isbn_df = isbn_df[~isbn_df['ISBN'].str[:3].isin(['978', '979'])]
whole_isbn_df = isbn_df[isbn_df['ISBN'].str[:3].isin(['978', '979'])]

broken_isbn_df
# Out:
#                 ISBN       Series Title  \
# 947    0020345542 (p                NaN
# 952    0020518609 (p  Scribner classics
# 980    0030705061 (p                NaN
# 1218   0060248742 (l                NaN
# 1219   0060248742 (l                NaN
# ...              ...                ...
# 76180  1887178228 (a                NaN
# 76181  1887178228 (a                NaN
# 79642  3822829668 (p  Basic art series.
# 79646  3822852961 (p                NaN
# 79647  382285302X (p                NaN
#
#                                     Title/Subtitle ISSN  \
# 947                 Great battles of the Civil War  NaN
# 952          The short stories of Ernest Hemingway  NaN
# 980    Paper flight : 48 models ready for take-off  NaN
# 1218                        Leaving home : stories  NaN
# 1219                        Leaving home : stories  NaN
# ...                                            ...  ...
# 76180                                 A world lost  NaN
# 76181                                 A world lost  NaN
# 79642                                     Futurism  NaN
# 79646                                  Renaissance  NaN
# 79647                                      Baroque  NaN
#
#                                                   Author  Publication Year  \
# 947                               Macdonald, John, 1945-            1992.0
# 952                        Hemingway, Ernest, 1899-1961.            1986.0
# 980                                     Botermans, Jack.            1984.0
# 1218   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# 1219   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# ...                                                  ...               ...
# 76180                              Berry, Wendell, 1934-            1996.0
# 76181                              Berry, Wendell, 1934-            1996.0
# 79642                              Martin, Sylvia, 1964-            2005.0
# 79646                                  Wundram, Manfred.            2006.0
# 79647                         Bauer, Hermann, 1929-2000.            2006.0
#
#                        Publisher Material Type Lexile  \
# 947           Collier/Macmillan,          Book    NaN
# 952               Collier Books,          Book    NaN
# 980                        Holt,          Book    NaN
# 1218   HarperCollins Publishers,          Book    NaN
# 1219   HarperCollins Publishers,          Book    NaN
# ...                          ...           ...    ...
# 76180             Counterpoint ;          Book    NaN
# 76181             Counterpoint ;          Book    NaN
# 79642                   Taschen,          Book    NaN
# 79646                   Taschen,          Book    NaN
# 79647                   Taschen,          Book    NaN
#
#                                       Subject
# 947    United States -- History -- 1861-1865.
# 952                            Short stories.
# 980                          Paper airplanes.
# 1218               Literature -- Collections.
# 1219                  Young adult literature.
# ...                                       ...
# 76180                    Kentucky -- Fiction.
# 76181                      Uncles -- Fiction.
# 79642                          Futurism (Art)
# 79646                  Painting, Renaissance.
# 79647                      Painting, Baroque.
#
# [2299 rows x 10 columns]

# %%
broken_isbn_df.loc[:,'ISBN'] = broken_isbn_df['ISBN'].apply(lambda x: '978' + str(x)[:10]) # Is 978 the right choice here??
broken_isbn_df
# Out:
#                 ISBN       Series Title  \
# 947    9780020345542                NaN
# 952    9780020518609  Scribner classics
# 980    9780030705061                NaN
# 1218   9780060248742                NaN
# 1219   9780060248742                NaN
# ...              ...                ...
# 76180  9781887178228                NaN
# 76181  9781887178228                NaN
# 79642  9783822829668  Basic art series.
# 79646  9783822852961                NaN
# 79647  978382285302X                NaN
#
#                                     Title/Subtitle ISSN  \
# 947                 Great battles of the Civil War  NaN
# 952          The short stories of Ernest Hemingway  NaN
# 980    Paper flight : 48 models ready for take-off  NaN
# 1218                        Leaving home : stories  NaN
# 1219                        Leaving home : stories  NaN
# ...                                            ...  ...
# 76180                                 A world lost  NaN
# 76181                                 A world lost  NaN
# 79642                                     Futurism  NaN
# 79646                                  Renaissance  NaN
# 79647                                      Baroque  NaN
#
#                                                   Author  Publication Year  \
# 947                               Macdonald, John, 1945-            1992.0
# 952                        Hemingway, Ernest, 1899-1961.            1986.0
# 980                                     Botermans, Jack.            1984.0
# 1218   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# 1219   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# ...                                                  ...               ...
# 76180                              Berry, Wendell, 1934-            1996.0
# 76181                              Berry, Wendell, 1934-            1996.0
# 79642                              Martin, Sylvia, 1964-            2005.0
# 79646                                  Wundram, Manfred.            2006.0
# 79647                         Bauer, Hermann, 1929-2000.            2006.0
#
#                        Publisher Material Type Lexile  \
# 947           Collier/Macmillan,          Book    NaN
# 952               Collier Books,          Book    NaN
# 980                        Holt,          Book    NaN
# 1218   HarperCollins Publishers,          Book    NaN
# 1219   HarperCollins Publishers,          Book    NaN
# ...                          ...           ...    ...
# 76180             Counterpoint ;          Book    NaN
# 76181             Counterpoint ;          Book    NaN
# 79642                   Taschen,          Book    NaN
# 79646                   Taschen,          Book    NaN
# 79647                   Taschen,          Book    NaN
#
#                                       Subject
# 947    United States -- History -- 1861-1865.
# 952                            Short stories.
# 980                          Paper airplanes.
# 1218               Literature -- Collections.
# 1219                  Young adult literature.
# ...                                       ...
# 76180                    Kentucky -- Fiction.
# 76181                      Uncles -- Fiction.
# 79642                          Futurism (Art)
# 79646                  Painting, Renaissance.
# 79647                      Painting, Baroque.
#
# [2299 rows x 10 columns]

# %%
isbn_df = pd.concat([broken_isbn_df, whole_isbn_df])
isbn_df
# Out:
#                 ISBN       Series Title  \
# 947    9780020345542                NaN
# 952    9780020518609  Scribner classics
# 980    9780030705061                NaN
# 1218   9780060248742                NaN
# 1219   9780060248742                NaN
# ...              ...                ...
# 79802  9798985282801                NaN
# 79803  9798985282801                NaN
# 79804  9798985282801                NaN
# 79805  9798985282801                NaN
# 79806  9798985282801                NaN
#
#                                     Title/Subtitle ISSN  \
# 947                 Great battles of the Civil War  NaN
# 952          The short stories of Ernest Hemingway  NaN
# 980    Paper flight : 48 models ready for take-off  NaN
# 1218                        Leaving home : stories  NaN
# 1219                        Leaving home : stories  NaN
# ...                                            ...  ...
# 79802             Women are the fiercest creatures  NaN
# 79803             Women are the fiercest creatures  NaN
# 79804             Women are the fiercest creatures  NaN
# 79805             Women are the fiercest creatures  NaN
# 79806             Women are the fiercest creatures  NaN
#
#                                                   Author  Publication Year  \
# 947                               Macdonald, John, 1945-            1992.0
# 952                        Hemingway, Ernest, 1899-1961.            1986.0
# 980                                     Botermans, Jack.            1984.0
# 1218   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# 1219   selected by Hazel Rochman and Darlene Z. McCam...            1997.0
# ...                                                  ...               ...
# 79802                                    Dunlop, Andrea.            2023.0
# 79803                                    Dunlop, Andrea.            2023.0
# 79804                                    Dunlop, Andrea.            2023.0
# 79805                                    Dunlop, Andrea.            2023.0
# 79806                                    Dunlop, Andrea.            2023.0
#
#                        Publisher Material Type Lexile  \
# 947           Collier/Macmillan,          Book    NaN
# 952               Collier Books,          Book    NaN
# 980                        Holt,          Book    NaN
# 1218   HarperCollins Publishers,          Book    NaN
# 1219   HarperCollins Publishers,          Book    NaN
# ...                          ...           ...    ...
# 79802               Zibby Books,          Book    NaN
# 79803               Zibby Books,          Book    NaN
# 79804               Zibby Books,          Book    NaN
# 79805               Zibby Books,          Book    NaN
# 79806               Zibby Books,          Book    NaN
#
#                                       Subject
# 947    United States -- History -- 1861-1865.
# 952                            Short stories.
# 980                          Paper airplanes.
# 1218               Literature -- Collections.
# 1219                  Young adult literature.
# ...                                       ...
# 79802                    Families -- Fiction.
# 79803                 \tFeminists -- Fiction.
# 79804         Friendship -- Women -- Fiction.
# 79805                       Thriller fiction.
# 79806                     Thrills and chills.
#
# [78890 rows x 10 columns]

# %%
# df = df.astype(str)
# df
# Out:
#                 ISBN Series Title  \
# 0                nan          nan
# 1                nan          nan
# 2                nan          nan
# 3                nan          nan
# 4                nan          nan
# ...              ...          ...
# 79802  9798985282801          nan
# 79803  9798985282801          nan
# 79804  9798985282801          nan
# 79805  9798985282801          nan
# 79806  9798985282801          nan
#
#                                           Title/Subtitle ISSN  \
# 0                                         The 60s reader  nan
# 1      200 years in Union : a pictorial history of Un...  nan
# 2                      1929, the year of the great crash  nan
# 3                      1929, the year of the great crash  nan
# 4                      1929, the year of the great crash  nan
# ...                                                  ...  ...
# 79802                   Women are the fiercest creatures  nan
# 79803                   Women are the fiercest creatures  nan
# 79804                   Women are the fiercest creatures  nan
# 79805                   Women are the fiercest creatures  nan
# 79806                   Women are the fiercest creatures  nan
#
#                       Author Publication Year                  Publisher  \
# 0            Haskins, James.           1987.0            Viking Kestrel,
# 1              Nash, Chester           1974.0  Union Historical Society,
# 2      Klingaman, William K.           1989.0              Harper & Row,
# 3      Klingaman, William K.           1989.0              Harper & Row,
# 4      Klingaman, William K.           1989.0              Harper & Row,
# ...                      ...              ...                        ...
# 79802        Dunlop, Andrea.           2023.0               Zibby Books,
# 79803        Dunlop, Andrea.           2023.0               Zibby Books,
# 79804        Dunlop, Andrea.           2023.0               Zibby Books,
# 79805        Dunlop, Andrea.           2023.0               Zibby Books,
# 79806        Dunlop, Andrea.           2023.0               Zibby Books,
#
#       Material Type Lexile                                            Subject
# 0              Book    nan                          United States -- History.
# 1              Book    nan          Union (Me.) -- History -- Pictoral works.
# 2              Book    nan              Depressions -- 1929 -- United States.
# 3              Book    nan                     Economic history -- 1918-1945.
# 4              Book    nan  United States -- Economic conditions -- 1918-1...
# ...             ...    ...                                                ...
# 79802          Book    nan                               Families -- Fiction.
# 79803          Book    nan                            \tFeminists -- Fiction.
# 79804          Book    nan                    Friendship -- Women -- Fiction.
# 79805          Book    nan                                  Thriller fiction.
# 79806          Book    nan                                Thrills and chills.
#
# [79807 rows x 10 columns]

# %%
isbn_df = isbn_df.astype(str)

# %%
# Drop duplicates based on relevant columns while keeping the first occurrence
isbn_df_unique = isbn_df.drop_duplicates(subset=['ISBN', 'Series Title', 'Title/Subtitle', 'ISSN', 
                                                  'Author', 'Publication Year', 'Publisher', 
                                                  'Material Type', 'Lexile'], keep='first')

# Group by 'ISBN' and combine the 'Subject' values
isbn_df_unique = isbn_df_unique.groupby('ISBN').agg({
    'Series Title': 'first',  # Keep the first value (they are the same for each ISBN)
    'Title/Subtitle': 'first',  # Same as above
    'ISSN': 'first',  # Same as above
    'Author': 'first',  # Same as above
    'Publication Year': 'first',  # Same as above
    'Publisher': 'first',  # Same as above
    'Material Type': 'first',  # Same as above
    'Lexile': 'first',  # Same as above
    'Subject': ', '.join  # Combine all unique 'Subject' values
}).reset_index()

isbn_df_unique
# Out:
#                 ISBN        Series Title  \
# 0      9780007439126  Martin Beck series
# 1      9780007511242                 nan
# 2      9780008183684                 nan
# 3      9780008256944                 nan
# 4      9780020198817  A Scribner classic
# ...              ...                 ...
# 11286  9789380741222     Campfire heroes
# 11287  9789629549992                 nan
# 11288  9798639873775                 nan
# 11289  9798663066952                 nan
# 11290  9798985282801                 nan
#
#                                           Title/Subtitle ISSN  \
# 0                           The Man Who Went Up in Smoke  nan
# 1                                        It's about love  nan
# 2                           Scotland the best 100 places  nan
# 3                              Lateral thinking puzzlers  nan
# 4                                       The great Gatsby  nan
# ...                                                  ...  ...
# 11286                     Gandhi : my life is my message  nan
# 11287                                   The great Gatsby  nan
# 11288                                    The fifth vital  nan
# 11289  Schitt's Creek Fun Facts : 80 fun facts and ev...  nan
# 11290                   Women are the fiercest creatures  nan
#
#                                                  Author Publication Year  \
# 0                                        Sjöwall, Maj.           2016.0
# 1                                       Camden, Steven.           2015.0
# 2                                  Irvine, Peter, 1948-           2017.0
# 3                                          Paul Sloane.           2016.0
# 4      Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1992.0
# ...                                                 ...              ...
# 11286                                     Quinn, Jason.           2013.0
# 11287  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           2012.0
# 11288                               Majlak, Mike, 1985-           2020.0
# 11289                                 Ortiz, Celestina.           2020.0
# 11290                                   Dunlop, Andrea.           2023.0
#
#                                                Publisher Material Type Lexile  \
# 0                                         Fourth Estate,          Book    nan
# 1                        HarperCollins Children's Books,          Book    nan
# 2                                               Collins,          Book    nan
# 3      Puzzlewright Press, an imprint of Sterling Pub...          Book    nan
# 4                                         Collier Books,          Book  1070L
# ...                                                  ...           ...    ...
# 11286            Campifre/Kalyani Navyug Media PVT Ltd.,          Book    nan
# 11287                                    Findaway World,         Sound    nan
# 11288                                       Mike Majlak,          Book    nan
# 11289                           Independently Published,          Book    nan
# 11290                                       Zibby Books,          Book    nan
#
#                                           Subject
# 0             Beck, Martin (Fictitious character)
# 1                                        Families
# 2                             Nature photography.
# 3                               Lateral thinking.
# 4                                             nan
# ...                                           ...
# 11286  Cartoons and comics., Cartoons and comics.
# 11287                                 Audiobooks.
# 11288                            Autobiographies.
# 11289                           American culture.
# 11290                        Families -- Fiction.
#
# [11291 rows x 10 columns]

# %%
def add_attributes(df):
    category_list = ['Title/Subtitle', 'Author', 'Copyright Date', 'Summary/Synopsis', 
                    'Series Name/Position', 'Genre', 'Form', 'Format', 'ISBN', 
                    'Page Count', 'Type']
    for category in category_list:
        if category not in df.columns:
            df.loc[category] = np.nan

add_attributes(isbn_df_unique)
add_attributes(nan_df)
isbn_df_unique
# Out:
#                 ISBN        Series Title  \
# 0      9780007439126  Martin Beck series
# 1      9780007511242                 nan
# 2      9780008183684                 nan
# 3      9780008256944                 nan
# 4      9780020198817  A Scribner classic
# ...              ...                 ...
# 11286  9789380741222     Campfire heroes
# 11287  9789629549992                 nan
# 11288  9798639873775                 nan
# 11289  9798663066952                 nan
# 11290  9798985282801                 nan
#
#                                           Title/Subtitle ISSN  \
# 0                           The Man Who Went Up in Smoke  nan
# 1                                        It's about love  nan
# 2                           Scotland the best 100 places  nan
# 3                              Lateral thinking puzzlers  nan
# 4                                       The great Gatsby  nan
# ...                                                  ...  ...
# 11286                     Gandhi : my life is my message  nan
# 11287                                   The great Gatsby  nan
# 11288                                    The fifth vital  nan
# 11289  Schitt's Creek Fun Facts : 80 fun facts and ev...  nan
# 11290                   Women are the fiercest creatures  nan
#
#                                                  Author Publication Year  \
# 0                                        Sjöwall, Maj.           2016.0
# 1                                       Camden, Steven.           2015.0
# 2                                  Irvine, Peter, 1948-           2017.0
# 3                                          Paul Sloane.           2016.0
# 4      Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1992.0
# ...                                                 ...              ...
# 11286                                     Quinn, Jason.           2013.0
# 11287  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           2012.0
# 11288                               Majlak, Mike, 1985-           2020.0
# 11289                                 Ortiz, Celestina.           2020.0
# 11290                                   Dunlop, Andrea.           2023.0
#
#                                                Publisher Material Type Lexile  \
# 0                                         Fourth Estate,          Book    nan
# 1                        HarperCollins Children's Books,          Book    nan
# 2                                               Collins,          Book    nan
# 3      Puzzlewright Press, an imprint of Sterling Pub...          Book    nan
# 4                                         Collier Books,          Book  1070L
# ...                                                  ...           ...    ...
# 11286            Campifre/Kalyani Navyug Media PVT Ltd.,          Book    nan
# 11287                                    Findaway World,         Sound    nan
# 11288                                       Mike Majlak,          Book    nan
# 11289                           Independently Published,          Book    nan
# 11290                                       Zibby Books,          Book    nan
#
#                                           Subject  Copyright Date  \
# 0             Beck, Martin (Fictitious character)             NaN
# 1                                        Families             NaN
# 2                             Nature photography.             NaN
# 3                               Lateral thinking.             NaN
# 4                                             nan             NaN
# ...                                           ...             ...
# 11286  Cartoons and comics., Cartoons and comics.             NaN
# 11287                                 Audiobooks.             NaN
# 11288                            Autobiographies.             NaN
# 11289                           American culture.             NaN
# 11290                        Families -- Fiction.             NaN
#
#        Summary/Synopsis  Series Name/Position  Genre  Form  Format  \
# 0                   NaN                   NaN    NaN   NaN     NaN
# 1                   NaN                   NaN    NaN   NaN     NaN
# 2                   NaN                   NaN    NaN   NaN     NaN
# 3                   NaN                   NaN    NaN   NaN     NaN
# 4                   NaN                   NaN    NaN   NaN     NaN
# ...                 ...                   ...    ...   ...     ...
# 11286               NaN                   NaN    NaN   NaN     NaN
# 11287               NaN                   NaN    NaN   NaN     NaN
# 11288               NaN                   NaN    NaN   NaN     NaN
# 11289               NaN                   NaN    NaN   NaN     NaN
# 11290               NaN                   NaN    NaN   NaN     NaN
#
#        Page Count  Type
# 0             NaN   NaN
# 1             NaN   NaN
# 2             NaN   NaN
# 3             NaN   NaN
# 4             NaN   NaN
# ...           ...   ...
# 11286         NaN   NaN
# 11287         NaN   NaN
# 11288         NaN   NaN
# 11289         NaN   NaN
# 11290         NaN   NaN
#
# [11291 rows x 18 columns]

# %%
short_df = isbn_df_unique.head(10)
short_df
# Out:
#             ISBN        Series Title                  Title/Subtitle ISSN  \
# 0  9780007439126  Martin Beck series    The Man Who Went Up in Smoke  nan
# 1  9780007511242                 nan                 It's about love  nan
# 2  9780008183684                 nan    Scotland the best 100 places  nan
# 3  9780008256944                 nan       Lateral thinking puzzlers  nan
# 4  9780020198817  A Scribner classic                The great Gatsby  nan
# 5  9780020199201       Collier books           This side of paradise  nan
# 6  9780020264801                 nan                     Ethan Frome  nan
# 7  978002034550X                 nan  Great battles of the Civil War  nan
# 8  9780020345542                 nan  Great battles of the Civil War  nan
# 9  9780020449313                 nan                    The yearling  nan
#
#                                              Author Publication Year  \
# 0                                    Sjöwall, Maj.           2016.0
# 1                                   Camden, Steven.           2015.0
# 2                              Irvine, Peter, 1948-           2017.0
# 3                                      Paul Sloane.           2016.0
# 4  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1992.0
# 5  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1986.0
# 6                        Wharton, Edith, 1862-1937.           1987.0
# 7                            Macdonald, John, 1945-           1992.0
# 8                            Macdonald, John, 1945-           1992.0
# 9             Rawlings, Marjorie Kinnan, 1896-1953.           1988.0
#
#                                            Publisher Material Type Lexile  \
# 0                                     Fourth Estate,          Book    nan
# 1                    HarperCollins Children's Books,          Book    nan
# 2                                           Collins,          Book    nan
# 3  Puzzlewright Press, an imprint of Sterling Pub...          Book    nan
# 4                                     Collier Books,          Book  1070L
# 5                                         Macmillan,          Book  1070L
# 6                                     Collier Books,          Book  1160L
# 7                                 Collier/Macmillan,          Book    nan
# 8                                 Collier/Macmillan,          Book    nan
# 9                                Aladdin Paperbacks,          Book   750L
#
#                                   Subject  Copyright Date  Summary/Synopsis  \
# 0     Beck, Martin (Fictitious character)             NaN               NaN
# 1                                Families             NaN               NaN
# 2                     Nature photography.             NaN               NaN
# 3                       Lateral thinking.             NaN               NaN
# 4                                     nan             NaN               NaN
# 5                                     nan             NaN               NaN
# 6                  New England -- Fiction             NaN               NaN
# 7  United States -- History -- 1861-1865.             NaN               NaN
# 8  United States -- History -- 1861-1865.             NaN               NaN
# 9                        Deer -- Fiction.             NaN               NaN
#
#    Series Name/Position  Genre  Form  Format  Page Count  Type
# 0                   NaN    NaN   NaN     NaN         NaN   NaN
# 1                   NaN    NaN   NaN     NaN         NaN   NaN
# 2                   NaN    NaN   NaN     NaN         NaN   NaN
# 3                   NaN    NaN   NaN     NaN         NaN   NaN
# 4                   NaN    NaN   NaN     NaN         NaN   NaN
# 5                   NaN    NaN   NaN     NaN         NaN   NaN
# 6                   NaN    NaN   NaN     NaN         NaN   NaN
# 7                   NaN    NaN   NaN     NaN         NaN   NaN
# 8                   NaN    NaN   NaN     NaN         NaN   NaN
# 9                   NaN    NaN   NaN     NaN         NaN   NaN

# %%
for isbn in short_df['ISBN']:
    if pd.isna(isbn):
        continue  # Skip if ISBN is NaN
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    response = requests.get(url)
    if response.status_code == 200: # Confirm request worked/is available
        book_data = response.json()
        if 'items' in book_data:
        # Extract book details from the API response
            book_info = book_data['items'][0]['volumeInfo']
            # Missing:
            # Series name and position
            # Form
            # Format
            book_details = {
                'ISBN#': isbn,
                'Title': book_info.get('title', np.nan),
                'Subtitle': np.nan, # Not available
                'Authors': ', '.join(book_info.get('authors', ['N/A'])),
                'Publisher': book_info.get('publisher', np.nan),
                'PublishedDate': book_info.get('publishedDate', np.nan),
                'CopyrightDate': np.nan, # Not available
                'Summary': book_info.get('description', 'No description available'), # NEED
                'Genre': ', '.join(book_info.get('categories', ['N/A'])), # NEED
                'PageCount': book_info.get('pageCount', np.nan), # NEED
                'Type': book_info.get('printType', np.nan), # Need
                'Categories': book_info.get('Categories', np.nan)
                # Type of book - ficiton, nonfiction, blended
            }
            # Accessing the correct row using ISBN in the DataFrame
            row_index = short_df[short_df['ISBN'] == isbn].index
            
            if not row_index.empty:  # Check if a matching ISBN was found
                row_index = row_index[0]  # Get the first (and expected only) match

                # Only update if the current value is NaN
                if pd.isna(short_df.loc[row_index, 'Title/Subtitle']):
                    short_df.loc[row_index, 'Title/Subtitle'] = book_details['Title']
                if pd.isna(short_df.loc[row_index, 'Author']):
                    short_df.loc[row_index, 'Author'] = book_details['Authors']
                if pd.isna(short_df.loc[row_index, 'Publication Year']):
                    short_df.loc[row_index, 'Publication Year'] = book_details['PublishedDate']
                if pd.isna(short_df.loc[row_index, 'Publisher']):
                    short_df.loc[row_index, 'Publisher'] = book_details['Publisher']
                if pd.isna(short_df.loc[row_index, 'Material Type']):
                    short_df.loc[row_index, 'Material Type'] = book_details['Type']
                if pd.isna(short_df.loc[row_index, 'Subject']):
                    short_df.loc[row_index, 'Subject'] = book_details['Genre']
                if pd.isna(short_df.loc[row_index, 'Summary/Synopsis']):
                    short_df.loc[row_index, 'Summary/Synopsis'] = book_details['Summary']
                if pd.isna(short_df.loc[row_index, 'Page Count']):
                    short_df.loc[row_index, 'Page Count'] = book_details['PageCount']
                # # ISBN Can't be NaN for this data scraping
                # if short_df['Title/Subtitle'][isbn] == np.nan:
                #     short_df['Title/Subtitle'][isbn] = book_details['Title']
                # if short_df['Author'][isbn] == np.nan:
                #     short_df['Author'][isbn] = book_details['Authors']
                # if short_df['Publication Year'][isbn] == np.nan:
                #     short_df['Publication Year'][isbn] = book_details['PublishedDate']
                # if short_df['Publisher'][isbn] == np.nan:
                #     short_df['Publisher'][isbn] = book_details['Publisher']
                # if short_df['Material Type'][isbn] == np.nan:
                #     short_df['Material Type'][isbn] = book_details['Type']
                # if short_df['Subject'][isbn] == np.nan:
                #     short_df['Subject'][isbn] = book_details['Genre']
                # if short_df['Summary/Synopsis'][isbn] == np.nan:
                #     short_df['Summary/Synopsis'][isbn] = book_details['Summary']
                # if short_df['Page Count'][isbn] == np.nan:
                #     short_df['Page Count'][isbn] = book_details['PageCount']
# Out:
# /var/folders/k6/lr3d617147z0f_fh76hx2dm40000gp/T/ipykernel_82088/3881808270.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Detective Martin Beck has just begun his holiday on a small island off the coast of Sweden. But when a neighbour gets a phone call, Beck finds himself packed off to Budapest, where a boorish journalist has vanished without a trace.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   short_df.loc[row_index, 'Summary/Synopsis'] = book_details['Summary']

# %%
short_df
# Out:
#             ISBN        Series Title                  Title/Subtitle ISSN  \
# 0  9780007439126  Martin Beck series    The Man Who Went Up in Smoke  nan
# 1  9780007511242                 nan                 It's about love  nan
# 2  9780008183684                 nan    Scotland the best 100 places  nan
# 3  9780008256944                 nan       Lateral thinking puzzlers  nan
# 4  9780020198817  A Scribner classic                The great Gatsby  nan
# 5  9780020199201       Collier books           This side of paradise  nan
# 6  9780020264801                 nan                     Ethan Frome  nan
# 7  978002034550X                 nan  Great battles of the Civil War  nan
# 8  9780020345542                 nan  Great battles of the Civil War  nan
# 9  9780020449313                 nan                    The yearling  nan
#
#                                              Author Publication Year  \
# 0                                    Sjöwall, Maj.           2016.0
# 1                                   Camden, Steven.           2015.0
# 2                              Irvine, Peter, 1948-           2017.0
# 3                                      Paul Sloane.           2016.0
# 4  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1992.0
# 5  Fitzgerald, F. Scott (Francis Scott), 1896-1940.           1986.0
# 6                        Wharton, Edith, 1862-1937.           1987.0
# 7                            Macdonald, John, 1945-           1992.0
# 8                            Macdonald, John, 1945-           1992.0
# 9             Rawlings, Marjorie Kinnan, 1896-1953.           1988.0
#
#                                            Publisher Material Type Lexile  \
# 0                                     Fourth Estate,          Book    nan
# 1                    HarperCollins Children's Books,          Book    nan
# 2                                           Collins,          Book    nan
# 3  Puzzlewright Press, an imprint of Sterling Pub...          Book    nan
# 4                                     Collier Books,          Book  1070L
# 5                                         Macmillan,          Book  1070L
# 6                                     Collier Books,          Book  1160L
# 7                                 Collier/Macmillan,          Book    nan
# 8                                 Collier/Macmillan,          Book    nan
# 9                                Aladdin Paperbacks,          Book   750L
#
#                                   Subject  Copyright Date  \
# 0     Beck, Martin (Fictitious character)             NaN
# 1                                Families             NaN
# 2                     Nature photography.             NaN
# 3                       Lateral thinking.             NaN
# 4                                     nan             NaN
# 5                                     nan             NaN
# 6                  New England -- Fiction             NaN
# 7  United States -- History -- 1861-1865.             NaN
# 8  United States -- History -- 1861-1865.             NaN
# 9                        Deer -- Fiction.             NaN
#
#                                     Summary/Synopsis  Series Name/Position  \
# 0  Detective Martin Beck has just begun his holid...                   NaN
# 1  Despite coming from different backgrounds, asp...                   NaN
# 2  Peter Irvine, bestselling author of Scotland t...                   NaN
# 3  The astonishing, beautiful new story for all r...                   NaN
# 4  Jay Gatsby had once loved beautiful, spoiled D...                   NaN
# 5  Here is the accomplished first novel that cata...                   NaN
# 6  Ethan Frome, a poor, downtrodden New England f...                   NaN
# 7                                                NaN                   NaN
# 8  17 of the Greatest Battles of the Civil War Co...                   NaN
# 9                                                NaN                   NaN
#
#    Genre  Form  Format  Page Count  Type
# 0    NaN   NaN     NaN         0.0   NaN
# 1    NaN   NaN     NaN         0.0   NaN
# 2    NaN   NaN     NaN         0.0   NaN
# 3    NaN   NaN     NaN       400.0   NaN
# 4    NaN   NaN     NaN       248.0   NaN
# 5    NaN   NaN     NaN       294.0   NaN
# 6    NaN   NaN     NaN       164.0   NaN
# 7    NaN   NaN     NaN         NaN   NaN
# 8    NaN   NaN     NaN         0.0   NaN
# 9    NaN   NaN     NaN         NaN   NaN

# %%
isbn = isbn_values[0]
url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"

response = requests.get(url)
if response.status_code == 200: # Confirm request worked/is available
    book_data = response.json()
    if 'items' in book_data:
        # Extract book details from the API response
        book_info = book_data['items'][0]['volumeInfo']
        # Missing:
        # Series name and position
        # Form
        # Format
        book_details = {
            'ISBN#': isbn,
            'Title': book_info.get('title', np.nan),
            'Subtitle': np.nan,
            'Authors': ', '.join(book_info.get('authors', ['N/A'])),
            'Publisher': book_info.get('publisher', np.nan),
            'PublishedDate': book_info.get('publishedDate', np.nan),
            'CopyrightDate': np.nan,
            'Summary': book_info.get('description', 'No description available'), # NEED
            'Genre': ', '.join(book_info.get('categories', ['N/A'])), # NEED
            'PageCount': book_info.get('pageCount', np.nan) # NEED
            # Type of book - ficiton, nonfiction, blended
        }

# Book title
# title = book_data['items'][0]['volumeInfo']['title']
# print(f"Title: {title}")

# %%
book_data
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1,
#  'items': [{'kind': 'books#volume',
#    'id': 'eZrztgAACAAJ',
#    'etag': '6a8Dfo+UKmk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/eZrztgAACAAJ',
#    'volumeInfo': {'title': 'The Man who Went Up in Smoke',
#     'authors': ['Maj Sjöwall', 'Per Wahlöö'],
#     'publisher': 'A Martin Beck Novel',
#     'publishedDate': '2011',
#     'description': 'Detective Martin Beck has just begun his holiday on a small island off the coast of Sweden. But when a neighbour gets a phone call, Beck finds himself packed off to Budapest, where a boorish journalist has vanished without a trace.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0007439121'},
#      {'type': 'ISBN_13', 'identifier': '9780007439126'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 0,
#     'printType': 'BOOK',
#     'categories': ['Beck, Martin (Fictitious character)'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=eZrztgAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=eZrztgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=eZrztgAACAAJ&dq=isbn:9780007439126&hl=&cd=1&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=eZrztgAACAAJ&dq=isbn:9780007439126&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/The_Man_who_Went_Up_in_Smoke.html?hl=&id=eZrztgAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=eZrztgAACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Detective Martin Beck has just begun his holiday on a small island off the coast of Sweden. But when a neighbour gets a phone call, Beck finds himself packed off to Budapest, where a boorish journalist has vanished without a trace.'}}]}

# %%
import requests
import pandas as pd
import time

unique_isbn_list = list(unique_isbn_values)

# List to store book data
book_data_list = []

# Loop over each ISBN and fetch data from Google Books API
for isbn in unique_isbn_list[:10]:
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    try:
        # Make the GET request
        response = requests.get(url)
        
        # Check if the response is successful (status code 200)
        if response.status_code == 200:
            book_data = response.json()

            # Check if 'items' is in the response (this indicates that data is available)
            if 'items' in book_data:
                # Extract book details from the API response
                book_info = book_data['items'][0]['volumeInfo']
                # Missing:
                    # Series name and position
                    # Form
                    # Format
                book_details = {
                    'ISBN#': isbn,
                    'Title': book_info.get('title', np.nan),
                    'Subtitle': np.nan,
                    'Authors': ', '.join(book_info.get('authors', ['N/A'])),
                    'Publisher': book_info.get('publisher', np.nan),
                    'PublishedDate': book_info.get('publishedDate', np.nan),
                    'CopyrightDate': np.nan,
                    'Summary': book_info.get('description', 'No description available'), # NEED
                    'Genre': ', '.join(book_info.get('categories', ['N/A'])), # NEED
                    'PageCount': book_info.get('pageCount', np.nan) # NEED
                    # Type of book - ficiton, nonfiction, blended
                }
                book_data_list.append(book_details)
            else:
                # Handle the case where no data is found for the ISBN
                print(f"No data found for ISBN {isbn}")
                book_details = {
                    'ISBN#': isbn,
                    'Title': np.nan,
                    'Subtitle': np.nan,
                    'Subtitle': np.nan,
                    'Authors': np.nan,
                    'Publisher': np.nan,
                    'PublishedDate': np.nan,
                    'CopyrightDate': np.nan,
                    'Summary': np.nan, # NEED
                    'Genre': np.nan, # NEED
                    'PageCount': np.nan # NEED
                    # Type of book - ficiton, nonfiction, blended
                }
                book_data_list.append(book_details)
        else:
            # If the response status code isn't 200, print an error message
            print(f"Error fetching data for ISBN {isbn}, Status Code: {response.status_code}")
    
    except requests.exceptions.RequestException as e:
        # Handle other exceptions such as network issues or timeout
        print(f"Error with request for ISBN {isbn}: {e}")
    
    # Sleep to prevent hitting API rate limits too quickly (optional but recommended for large datasets)
    time.sleep(1)

# Convert the list of book data to a DataFrame for easier manipulation/inspection
book_data_df = pd.DataFrame(book_data_list)

# Optionally, save the data to an Excel file
book_data_df.to_excel('book_data.xlsx', index=False)

# Print the DataFrame or inspect the first few rows
book_data_df
# Out:
# No data found for ISBN 9781421540764
#            ISBN#                         Title  Subtitle  \
# 0  9780525564201  My Sister, the Serial Killer       NaN
# 1  9781534474529      How to Change Everything       NaN
# 2  9781338670905             Forged by Reading       NaN
# 3  9781662515125                 The Spy Coast       NaN
# 4  9781421527734                   Brave Story       NaN
# 5  9780062394415             She Rides Shotgun       NaN
# 6  9780593466322             Shrines of Gaiety       NaN
# 7  9781421540764                           NaN       NaN
# 8  9780399171611          The Wrath & the Dawn       NaN
# 9  9781250153296             Untitled Flatiron       NaN
#
#                        Authors                         Publisher  \
# 0          Oyinkan Braithwaite                            Anchor
# 1                  Naomi Klein  Atheneum Books for Young Readers
# 2  Kylene Beers, Robert Probst           Scholastic Professional
# 3               Tess Gerritsen                   Thomas & Mercer
# 4                Miyuki Miyabe                         Haikasoru
# 5                Jordan Harper                              Ecco
# 6                Kate Atkinson                            Anchor
# 7                          NaN                               NaN
# 8                 Renée Ahdieh                           Penguin
# 9            Untitled Flatiron                    Flatiron Books
#
#   PublishedDate  CopyrightDate  \
# 0    2019-07-30            NaN
# 1    2021-02-23            NaN
# 2       2020-12            NaN
# 3    2023-10-17            NaN
# 4    2009-11-17            NaN
# 5    2018-03-13            NaN
# 6    2023-05-02            NaN
# 7           NaN            NaN
# 8    2015-05-12            NaN
# 9    2019-11-05            NaN
#
#                                              Summary  \
# 0  ONE OF TIME MAGAZINE'S 100 BEST MYSTERY AND TH...
# 1  “[A] uniquely inclusive perspective that will ...
# 2  Bestselling authors Beers and Probst explore w...
# 3  A retired CIA operative in small-town Maine ta...
# 4  Wataru Mitani has to grow up fast, and not jus...
# 5  *WINNER OF A 2018 EDGAR AWARD FOR BEST DEBUT N...
# 6  NEW YORK TIMES BESTSELLER • The award-winning ...
# 7                                                NaN
# 8  #1 New York Times Bestseller A sumptuous and e...
# 9                           No description available
#
#                        Genre  PageCount
# 0                    Fiction      241.0
# 1        Juvenile Nonfiction      336.0
# 2                        N/A      208.0
# 3                    Fiction        0.0
# 4           Juvenile Fiction        0.0
# 5                    Fiction      272.0
# 6                    Fiction      449.0
# 7                        NaN        NaN
# 8        Young Adult Fiction      418.0
# 9  Biography & Autobiography      320.0

# %%
file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file
#
# NameError: name 'file' is not defined

# %%
url = f"http://openlibrary.org/api/volumes/brief/isbn/0596156715.json"
# Make the GET request
response = requests.get(url)
response

#         # Check if 'items' is in the response (this indicates that data is available)
#         if 'items' in book_data:
#             # Extract book details from the API response
#             book_info = book_data['items'][0]['volumeInfo']
#             # Missing:
#                 # Series name and position
#                 # Form
#                 # Format
#             book_details = {
#                 'ISBN': isbn,
#                 'title': book_info.get('title', 'N/A'),
#                 'authors': ', '.join(book_info.get('authors', ['N/A'])),
#                 'publisher': book_info.get('publisher', 'N/A'),
#                 'publishedDate': book_info.get('publishedDate', 'N/A'),
#                 'Summary': book_info.get('description', 'No description available'), # NEED
#                 'Genre': ', '.join(book_info.get('categories', ['N/A'])), # NEED
#                 'pageCount': book_info.get('pageCount', 'N/A'),
#             }
#             book_data_list.append(book_details)
#         else:
#             # Handle the case where no data is found for the ISBN
#             print(f"No data found for ISBN {isbn}")
#     else:
#         # If the response status code isn't 200, print an error message
#     print(f"Error fetching data for ISBN {isbn}, Status Code: {response.status_code}")
    
# except requests.exceptions.RequestException as e:
#     # Handle other exceptions such as network issues or timeout
#     print(f"Error with request for ISBN {isbn}: {e}")
    
#     # Sleep to prevent hitting API rate limits too quickly (optional but recommended for large datasets)
#     time.sleep(1)

# # Convert the list of book data to a DataFrame for easier manipulation/inspection
# book_data_df = pd.DataFrame(book_data_list)

# # Optionally, save the data to an Excel file
# book_data_df.to_excel('book_data.xlsx', index=False)

# # Print the DataFrame or inspect the first few rows
# book_data_df.head()
# Out:
# <Response [200]>
